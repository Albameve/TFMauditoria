# %% [markdown]
# __Título TFM: Modelos de Aprendizaje Automático para procesos de auditoría contables__
#
# __Alumna: Alba Mena Vera__
#
# __Variable objetivo : Grupo de gastos __

# %% [markdown]
# #Introducción
#
# La BBDD ha sido obtenido de la página web de datos del Gobierno de España.
#
# La plataforma datos.gob.es se constituye como el punto de encuentro entre las administraciones, las empresas y los ciudadanos interesados en la apertura de la información pública y en el desarrollo de servicios avanzados basados en datos.
#
# Datos.gob.es permite la interacción del visitante y ofrece visibilidad a las actuaciones que se realizan en el marco de la Iniciativa Aporta, la estrategia de datos abiertos de España.
#
# Datos.gob.es que organiza y gestiona el Catálogo de Información Pública del sector público. Asimismo, desde la plataforma proporciona información general, materiales formativos y noticias de actualidad sobre la reutilización de la información del sector público.
#
# El conjunto de datos que voy a utilizar es la Facturación de CTPDA de Andalucia y su grupo de gastos como variable objetivo clasificadora.

# %% [markdown]
# # Conocimiento y limpieza del dataset:

# %% [markdown]
# ## Librerías necesarias

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.mlab as mlab
import matplotlib
#import plotly.tools as tls
#from plotly.offline import init_notebook_mode, iplot, plot
#import plotly.graph_objs as go
import seaborn as sns
import datetime
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.model_selection import train_test_split
from sklearn.svm import SVC
from sklearn.metrics import accuracy_score
from sklearn.preprocessing import LabelEncoder
from nltk.corpus import stopwords
from nltk.stem import PorterStemmer
from nltk.tokenize import word_tokenize
import re
import string
import unicodedata
from nltk.corpus import stopwords
from nltk.stem import PorterStemmer
from nltk.tokenize import word_tokenize

import nltk
nltk.download('punkt')
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package punkt to /Users/albamena/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/albamena/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %% [markdown]
# Link a la base de datos
# https://www.juntadeandalucia.es/datosabiertos/portal/dataset/facturacion

# %% [markdown]
# ## Lectura de la fuente de datos

# %%
df=pd.read_excel('facturacion-may-24u.xlsx')

# %% [markdown]
# Se leen las primeras 5 líneas del dataset para dar una visión general de su contenido:

# %%
df
# Out:
#      Fecha Entrada Registro  Importe Total        GRUPO DE GASTOS  \
# 0                2019-01-10           0.33         COMUNICACIONES
# 1                2021-02-03           1.00       VEHÍCULO OFICIAL
# 2                2023-06-26           1.00  ACTIVIDAD DEL CONSEJO
# 3                2016-09-08           1.17         COMUNICACIONES
# 4                2016-09-08           1.17         COMUNICACIONES
# ...                     ...            ...                    ...
# 2699             2020-06-02        9376.87                   SEDE
# 2700             2021-11-26        9408.57  ACTIVIDAD DEL CONSEJO
# 2701             2022-03-02        9519.07  ACTIVIDAD DEL CONSEJO
# 2702             2021-12-21        9747.51  ACTIVIDAD DEL CONSEJO
# 2703             2020-01-08        9765.83             ENCOMIENDA
#
#                              SUBGRUPO       Denominación Factura  \
# 0                  TELEFONÍA-INTERNET  LOTE 5 VOZ FIJA SEPTIEMBR
# 1         COMBUSTIBLE,LAVADOS Y OTROS           LAVADOS ENERO 21
# 2                           PROTOCOLO  COMISION ENTE, C, PROTOC,
# 3                  TELEFONÍA-INTERNET   LOTE 9 AC INTERN 2 MARZO
# 4                  TELEFONÍA-INTERNET   LOTE 9 AC INTERN 2 ABRIL
# ...                               ...                        ...
# 2699                    MANTENIMIENTO    VIG–SEG,CTPDA 1 A 31/05
# 2700  MATERIAL INFORMÁTICO Y  OFICINA      CABINA ALMACENAM, SAN
# 2701    DOCUMENTACIÓN Y PUBLICACIONES       RENOV,SUSCRIPBD 2022
# 2702               PLANES Y PROGRAMAS   DES, DE SIST,INF, NOV,21
# 2703                         SANDETEL      GEST INF TIC DIC 2019
#
#                     Denominación Acreedor
# 0     TELEFONICA DE ESPAÑA SAU TELEFONICA
# 1                               SOLRED SA
# 2     EXCMO CABILDO DE LA S M Y P I CATED
# 3     TELEFONICA DE ESPAÑA SAU TELEFONICA
# 4     TELEFONICA DE ESPAÑA SAU TELEFONICA
# ...                                   ...
# 2699                    SECURITY WORLD SA
# 2700  SOLUTIA INNOVAWORLD TECHNOLOGIES, S
# 2701               EDITORIAL ARANZADI SAU
# 2702              SOLTEL IT SOLUTIONS SLU
# 2703   SDAD AND PARA EL DESARROLLO DE LAS
#
# [2704 rows x 6 columns]

# %% [markdown]
# Eliminamos los duplicados que pueda haber

# %%
df=df.drop_duplicates()
df
# Out:
#      Fecha Entrada Registro  Importe Total        GRUPO DE GASTOS  \
# 0                2019-01-10           0.33         COMUNICACIONES
# 1                2021-02-03           1.00       VEHÍCULO OFICIAL
# 2                2023-06-26           1.00  ACTIVIDAD DEL CONSEJO
# 3                2016-09-08           1.17         COMUNICACIONES
# 4                2016-09-08           1.17         COMUNICACIONES
# ...                     ...            ...                    ...
# 2699             2020-06-02        9376.87                   SEDE
# 2700             2021-11-26        9408.57  ACTIVIDAD DEL CONSEJO
# 2701             2022-03-02        9519.07  ACTIVIDAD DEL CONSEJO
# 2702             2021-12-21        9747.51  ACTIVIDAD DEL CONSEJO
# 2703             2020-01-08        9765.83             ENCOMIENDA
#
#                              SUBGRUPO       Denominación Factura  \
# 0                  TELEFONÍA-INTERNET  LOTE 5 VOZ FIJA SEPTIEMBR
# 1         COMBUSTIBLE,LAVADOS Y OTROS           LAVADOS ENERO 21
# 2                           PROTOCOLO  COMISION ENTE, C, PROTOC,
# 3                  TELEFONÍA-INTERNET   LOTE 9 AC INTERN 2 MARZO
# 4                  TELEFONÍA-INTERNET   LOTE 9 AC INTERN 2 ABRIL
# ...                               ...                        ...
# 2699                    MANTENIMIENTO    VIG–SEG,CTPDA 1 A 31/05
# 2700  MATERIAL INFORMÁTICO Y  OFICINA      CABINA ALMACENAM, SAN
# 2701    DOCUMENTACIÓN Y PUBLICACIONES       RENOV,SUSCRIPBD 2022
# 2702               PLANES Y PROGRAMAS   DES, DE SIST,INF, NOV,21
# 2703                         SANDETEL      GEST INF TIC DIC 2019
#
#                     Denominación Acreedor
# 0     TELEFONICA DE ESPAÑA SAU TELEFONICA
# 1                               SOLRED SA
# 2     EXCMO CABILDO DE LA S M Y P I CATED
# 3     TELEFONICA DE ESPAÑA SAU TELEFONICA
# 4     TELEFONICA DE ESPAÑA SAU TELEFONICA
# ...                                   ...
# 2699                    SECURITY WORLD SA
# 2700  SOLUTIA INNOVAWORLD TECHNOLOGIES, S
# 2701               EDITORIAL ARANZADI SAU
# 2702              SOLTEL IT SOLUTIONS SLU
# 2703   SDAD AND PARA EL DESARROLLO DE LAS
#
# [2704 rows x 6 columns]

# %% [markdown]
# Observamos que no hay duplicados

# %% [markdown]
# ## Tipos de variables y cantidad de instacias

# %% [markdown]
# Compruebo los tipos y la cantidad de instancia. De este resultado compruebo que el conjunto de datos tiene **2704  filas o instancias y 6 columnas o variables**:

# %%
print(df.shape)
# Out:
# (2704, 6)

# %% [markdown]
# También puedo ver que variables son numéricas y cuales categóricas, las numéricas potencialmente no tendré que cambiar nada de ellas. Compruebo los tipos de variables que contiene el dataset con dtypes:

# %%
print(df.dtypes)
# Out:
# Fecha Entrada Registro    datetime64[ns]
# Importe Total                    float64
# GRUPO DE GASTOS                   object
# SUBGRUPO                          object
# Denominación Factura              object
# Denominación Acreedor             object
# dtype: object

# %% [markdown]
# Esto es otra forma de ver el tipo de variables que tengo, Compruebo de que tipo son mis variables:
# object=variables alfanumericas, datetime fecha, entero... Vemos que todas son object

# %% [markdown]
# Renombramos las variables para que sea más cómodo

# %%
df.rename(columns={'Fecha Entrada Registro':'fecha_entrada_registro',
                        'Importe Total':'importe_total','GRUPO DE GASTOS': 'grupo_gastos','SUBGRUPO':'subgrupo','Denominación Factura':'denominacion_factura','Denominación Acreedor':'denominacion_acreedor'   },
               inplace=True)
df.columns
# Out:
# Index(['fecha_entrada_registro', 'importe_total', 'grupo_gastos', 'subgrupo',
#        'denominacion_factura', 'denominacion_acreedor'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2704 entries, 0 to 2703
# Data columns (total 6 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   fecha_entrada_registro  2704 non-null   datetime64[ns]
#  1   importe_total           2704 non-null   float64
#  2   grupo_gastos            2704 non-null   object
#  3   subgrupo                2704 non-null   object
#  4   denominacion_factura    2704 non-null   object
#  5   denominacion_acreedor   2703 non-null   object
# dtypes: datetime64[ns](1), float64(1), object(4)
# memory usage: 126.9+ KB

# %% [markdown]
# A continuación veo el número de columnas de mi dataset

# %%
df.columns
# Out:
# Index(['fecha_entrada_registro', 'importe_total', 'grupo_gastos', 'subgrupo',
#        'denominacion_factura', 'denominacion_acreedor'],
#       dtype='object')

# %%
df.describe()
# Out:
#               fecha_entrada_registro  importe_total
# count                           2704    2704.000000
# mean   2020-02-09 08:09:56.449704192    4140.458861
# min              2016-02-09 00:00:00 -327196.000000
# 25%              2018-02-19 18:00:00      72.342500
# 50%              2019-12-18 00:00:00     195.610000
# 75%              2021-12-16 06:00:00     680.762500
# max              2023-12-28 00:00:00  891437.000000
# std                              NaN   42282.723913

# %%
print(df.isnull().sum())
# Out:
# fecha_entrada_registro    0
# importe_total             0
# grupo_gastos              0
# subgrupo                  0
# denominacion_factura      0
# denominacion_acreedor     1
# dtype: int64

# %% [markdown]
# ### Valores perdidos
# Compruebo los valores que son nulos en cada una de las variables del dataset.

# %% [markdown]
# #### Missing Data Heatmap
# Cuando hay un número menor de características, podemos visualizar los datos que faltan a través del mapa de calor. El siguiente mapa de calor muestra en amarillo los missing values de cada variable.

# %%
cols = df.columns[:7] # quiero ver todas mis columnas
colours = ['#00FFFF', '#ffff00'] # Especifica el color - amarillo es missing y azul no es missing.
fig, ax = plt.subplots(figsize=(10, 7))
sns.heatmap(df[cols].isnull(), cmap=sns.color_palette(colours))
plt.savefig('missingheat.png')

# %% [markdown]
# #### Porcentaje de missing values
#
# Observamos que no hay missing values en nuestro data set.

# %%
for col in df.columns:
    pct_missing = np.mean(df[col].isnull())
    print('{} - {}%'.format(col, round(pct_missing*100)))
    plt.barh(col, round(pct_missing*100))
plt.savefig('Porcentaje_de_missing_values.png')
# Out:
# fecha_entrada_registro - 0%
# importe_total - 0%
# grupo_gastos - 0%
# subgrupo - 0%
# denominacion_factura - 0%
# denominacion_acreedor - 0%

# %% [markdown]
# ###Convertir variables de tipo string a valores numéricas

# %% [markdown]
# ###Consolidación de la variable grupo_gastos

# %%
x=df['grupo_gastos'].value_counts()
print(x,x.index)
sns.barplot(x=x.values, y=x.index, alpha=0.8)
# Out:
# grupo_gastos
# COMUNICACIONES                             593
# SEDE                                       558
# ACTIVIDAD                                  430
# ACTIVIDAD DEL CONSEJO                      341
# INDEMNIZACIONES POR RAZÓN DEL SERVICIO     335
# INDEMNIZACIÓN RAZÓN SERVICIO               138
# VEHÍCULO OFICIAL                           113
# ENCOMIENDAS                                 85
# ENCARGO A MEDIO PROPIO                      49
# VEHíCULO OFICIAL                            20
# INDEMNIZACIONES POR RAZÓN  DEL SERVICIO     19
# ENCOMIENDA                                  11
# INDEMNIZACIÓN                                6
# MATERIAL INFORMÁTICO Y DE OFICINA            3
# VEHÍCULO                                     2
# Í                                            1
# Name: count, dtype: int64 Index(['COMUNICACIONES', 'SEDE', 'ACTIVIDAD', 'ACTIVIDAD DEL CONSEJO',
#        'INDEMNIZACIONES POR RAZÓN DEL SERVICIO',
#        'INDEMNIZACIÓN RAZÓN SERVICIO', 'VEHÍCULO OFICIAL', 'ENCOMIENDAS',
#        'ENCARGO A MEDIO PROPIO', 'VEHíCULO OFICIAL',
#        'INDEMNIZACIONES POR RAZÓN  DEL SERVICIO', 'ENCOMIENDA',
#        'INDEMNIZACIÓN', 'MATERIAL INFORMÁTICO Y DE OFICINA', 'VEHÍCULO', 'Í'],
#       dtype='object', name='grupo_gastos')
# <Axes: ylabel='grupo_gastos'>

# %%
df['grupo_gastos'].value_counts()
# Out:
# grupo_gastos
# COMUNICACIONES                             593
# SEDE                                       558
# ACTIVIDAD                                  430
# ACTIVIDAD DEL CONSEJO                      341
# INDEMNIZACIONES POR RAZÓN DEL SERVICIO     335
# INDEMNIZACIÓN RAZÓN SERVICIO               138
# VEHÍCULO OFICIAL                           113
# ENCOMIENDAS                                 85
# ENCARGO A MEDIO PROPIO                      49
# VEHíCULO OFICIAL                            20
# INDEMNIZACIONES POR RAZÓN  DEL SERVICIO     19
# ENCOMIENDA                                  11
# INDEMNIZACIÓN                                6
# MATERIAL INFORMÁTICO Y DE OFICINA            3
# VEHÍCULO                                     2
# Í                                            1
# Name: count, dtype: int64

# %%
import unicodedata
# Función para eliminar tildes
def quitar_tildes(texto):
    # Check if the input is a string, if not convert to string
    if not isinstance(texto, str):
        texto = str(texto)
    return unicodedata.normalize('NFKD', texto).encode('ascii', 'ignore').decode('utf-8')


def consolidar(x):
    # Quita tildes y normaliza el input
    x = quitar_tildes(x).upper().strip()

    if x == 'ACTIVIDAD' or x == 'ACTIVIDAD DEL CONSEJO':
        return 'ACTIVIDAD'
    elif x in ['INDEMNIZACIONES POR RAZON DEL SERVICIO', 'INDEMNIZACION RAZON SERVICIO', 'INDEMNIZACIONES POR RAZON DEL SERVICIO', 'INDEMNIZACION', 'INDEMNIZACIONES POR RAZON DEL SERVICIO','INDEMNIZACIONES POR RAZON  DEL SERVICIO']:
        return 'INDEMNIZACIONES'
    elif x in ['VEHICULO OFICIAL', 'VEHICULO','I']:
        return 'VEHICULO'
    elif x in ['ENCOMIENDAS', 'ENCOMIENDA']:
        return 'ENCOMIENDAS'
    elif x in ['MATERIAL INFORMATICO Y OFICINA', 'MATERIAL INFORMATICO Y DE OFICINA', 'MATERIAL INFORMATICO Y OF.']:
        return 'ACTIVIDAD'
    elif x in ['SUMINISTROS', 'SUMINISTRO']:
        return 'SUMINISTRO'
    elif x in ['PUBLICIDAD Y COMUNICACION', 'CAMPANAS PUBLICIDAD', 'PUBLICIDAD Y DOCUMENTACION', 'PUBLICIDAD']:
        return 'PUBLICIDAD'
    elif x in ['COMBUSTIBLE Y LAVADOS', 'COMBUSTIBLE, LAVADOS Y OTROS', 'COMBUSTIBLE-LAVADO']:
        return 'COMBUSTIBLE Y LAVADOS'
    elif x in ['REUNIONES, CONFERENCIAS Y CURSOS', 'REUNIONES Y CONFERENCIAS']:
        return 'REUNIONES, CONFERENCIAS Y CURSOS'
    elif x in ['ASISTENCIA SESIONES COMISION CONSULTIVA', 'ASISTNCIA SESIONES COMISION CONSULTIVA', 'ASISTENCIA SESIONES']:
        return 'ASISTENCIA SESIONES COMISION CONSULTIVA'
    elif x in ['TELEFONIA-INTERNET', 'TELEFONIA E INTERNET']:
        return 'TELEFONIA E INTERNET'
    elif x in ['SERV. GESTION INFRAESTRUCTURAS TIC', 'SERVICIO DE GESTION DE INFR. TIC']:
        return 'SERV. GESTION INFRAESTRUCTURAS TIC'
    elif x in ['FORMACION INTERNA']:
        return 'FORMACION INTERNA'
    elif x in ['ADQUISICION', 'ADQ LIBROS/DOCUMENTACION']:
        return 'ADQUISICION'
    elif x in ['GASTOS CONTENCIOSOS', 'GASTOS CONTENCIOSO']:
        return 'GASTOS CONTENCIOSOS'
    elif x in ['MANTENIMIENTO', 'MANTENIMIENTO COCHE']:
        return 'MANTENIMIENTO'
    elif x in ['VESTUARIO', 'VESTUARIO PERSONAL LABORAL']:
        return 'VESTUARIO'
    elif x == 'COMUNICACIONES':
        return 'COMUNICACIONES'
    elif x == 'SEDE':
        return 'SEDE'
    else:
        return x

df['grupo_gastos'] = df['grupo_gastos'].apply(quitar_tildes)
df['grupo_gastos_n'] = df['grupo_gastos'].map(lambda x: consolidar(x))

# %%
df['grupo_gastos_n'].value_counts()
# Out:
# grupo_gastos_n
# ACTIVIDAD                 774
# COMUNICACIONES            593
# SEDE                      558
# INDEMNIZACIONES           498
# VEHICULO                  136
# ENCOMIENDAS                96
# ENCARGO A MEDIO PROPIO     49
# Name: count, dtype: int64

# %%
x=df['grupo_gastos_n'].value_counts()
print(x,x.index)
sns.barplot(x=x.values, y=x.index, alpha=0.8)
# Out:
# grupo_gastos_n
# ACTIVIDAD                 774
# COMUNICACIONES            593
# SEDE                      558
# INDEMNIZACIONES           498
# VEHICULO                  136
# ENCOMIENDAS                96
# ENCARGO A MEDIO PROPIO     49
# Name: count, dtype: int64 Index(['ACTIVIDAD', 'COMUNICACIONES', 'SEDE', 'INDEMNIZACIONES', 'VEHICULO',
#        'ENCOMIENDAS', 'ENCARGO A MEDIO PROPIO'],
#       dtype='object', name='grupo_gastos_n')
# <Axes: ylabel='grupo_gastos_n'>

# %%
def grupogastoscod(x): 
    if x=="ACTIVIDAD" :
        return 0 
    elif x=="COMUNICACIONES" :
        return 1
    elif x=="ENCARGO A MEDIO PROPIO" :
        return 2 
    elif x=="ENCOMIENDAS" :
        return 3
    elif x=="INDEMNIZACIONES" :
        return 4
    elif x=="SEDE" :
        return 5
    elif x=="VEHICULO" :
        return 6
df['df_GrupoGastos'] =df['grupo_gastos_n'].map(lambda x: grupogastoscod(x))

# %% [markdown]
# ###Consolidación de la variable subgrupo

# %%
x=df['subgrupo'].value_counts()
print(x,x.index)
sns.barplot(x=x.values, y=x.index, alpha=0.8)
# Out:
# subgrupo
# TELEFONÍA-INTERNET                    467
# DIETAS                                446
# MANTENIMIENTO                         364
# MATERIAL INFORMÁTICO Y DE OFICINA     209
# POSTAL                                120
#                                      ...
# MATERIAL INFORMÁTICO  Y DE OFICINA      1
# MATERIAL INFORMÁTICO Y OF,              1
# ADQ,LIBROS/DOCUMENTACIÓN                1
# FORMACION INTERNA                       1
# IDENTIDAD CORPORATIVA                   1
# Name: count, Length: 67, dtype: int64 Index(['TELEFONÍA-INTERNET', 'DIETAS', 'MANTENIMIENTO',
#        'MATERIAL INFORMÁTICO Y DE OFICINA', 'POSTAL', 'SUMINISTROS',
#        'GASTOS CONTENCIOSOS', 'SANDETEL', 'DOCUMENTACIÓN Y PUBLICACIONES',
#        'COMBUSTIBLE Y LAVADOS', 'PLANES Y PROGRAMAS', 'TRIBUTOS',
#        'ADQ, LIBROS / DOCUMENTACIÓN', 'FORMACIÓN INTERNA',
#        'SERV, GESTIÓN INFRAESTRUCTURAS TIC', 'SUMINISTRO',
#        'REUNIONES, CONFERENCIAS Y CURSOS', 'MATERIAL INFORMÁTICO Y OFICINA',
#        'MATERIAL INFORMÁTICO Y  OFICINA', 'COMBUSTIBLE,LAVADOS Y OTROS',
#        'REUNIONES', 'PUBLICIDAD Y COMUNICACIÓN', 'CENTRA', 'COMBUSTIBLE',
#        'INDEMNIZACIONES POR RAZÓN DEL SERVICIO',
#        'REUNIONES, CONFERENCIAS Y CURSOS ', 'PROTOCOLO', 'COLEGIACIÓN',
#        'ASISTENCIA SESIONES COMISION CONSULTIVA',
#        'ASISTENCIA SESIONES COMISIÓN CONSULTIVA', 'VESTUARIO PERSONAL LABORAL',
#        'MANTENIMIENTO COCHE', 'CAMPAÑAS PUBLICIDAD', 'VESTUARIO',
#        'SERVICIOS GESTIÓN INFRAESTRUCTURAS TIC',
#        'PREVENCIÓN RIESGOS LABORALES', 'ASISTENCIA SESIONES',
#        'COMBUSTIBLE, LAVADOS Y OTROS', 'ADQ LIBROS/DOCUMENTACIÓN',
#        'GASTOS CONTECIOSOS', 'COMISION SELECCION CONCURSO',
#        'MATERIAL INFORMATICO', 'COMBUSTIBLE Y LAVADO',
#        'REUNIONES,CONFERENCIA Y CURSOS', 'PUBLICIDAD',
#        'PUBLICIDAD Y DOCUMENTACIÓN', 'GASTOS  CONTENCIOSO',
#        'SERVICIO DE GESTIÓN DE INFR, TIC',
#        'ASISTNCIA SESIONES COMISIÓN CONSULTIVA', 'COMBUSTIBLE-LAVADO',
#        'TELEFONÍA E INTERNET', 'REUNIONES Y CONFERENCIAS',
#        'REUNIONES,CONFERENCIAS Y CURSOS',
#        'SERVICIO GESTIÓN DE INFRAESTRUCTURAS',
#        'SERVICIO DE GESTION DE INFR, TIC', 'GASTOS DE REPRESENTACIÓN',
#        'SERVICIO  GESTIÓN  INFRAESTRUCTURAS TIC',
#        'COMBUSTIBLES,LAVADOS Y OTROS', 'ADQUISICIÓN', 'MA NTENIMIENTO',
#        'COMUNICACIÓN', 'TRADUCCIÓN', 'MATERIAL INFORMÁTICO  Y DE OFICINA',
#        'MATERIAL INFORMÁTICO Y OF,', 'ADQ,LIBROS/DOCUMENTACIÓN',
#        'FORMACION INTERNA', 'IDENTIDAD CORPORATIVA'],
#       dtype='object', name='subgrupo')
# <Axes: ylabel='subgrupo'>

# %%
import unicodedata
# Función para eliminar tildes
def quitar_tildes(texto):
    # Check if the input is a string, if not convert to string
    if not isinstance(texto, str):
        texto = str(texto)
    return unicodedata.normalize('NFKD', texto).encode('ascii', 'ignore').decode('utf-8')

def discretiza_subgrupo(subgrupo):

    if subgrupo in ['TELEFONIA-INTERNET', 'TELEFONIA E INTERNET']:
        return 'TELEFONIA E INTERNET'
    elif subgrupo in ['MATERIAL INFORMATICO Y DE OFICINA', 'MATERIAL INFORMATICO Y OFICINA', 'MATERIAL INFORMATICO Y OF.','MATERIAL INFORMATICO','MATERIAL INFORMATICO Y DE OFICINA','MATERIAL INFORMATICO Y OFICINA','MATERIAL INFORMATICO Y OF','MATERIAL INFORMATICO Y OFICINA','MATERIAL INFORMATICO Y OF,',
      'MATERIAL INFORMATICO  Y DE OFICINA','MATERIAL INFORMATICO Y  OFICINA']:
        return 'MATERIAL INFORMATICO Y DE OFICINA'
    elif subgrupo in ['SERVICIO DE GESTION DE INFR. TIC', 'SERV. GESTION INFRAESTRUCTURAS TIC', 'SERVICIO GESTION DE INFRAESTRUCTURAS','SERV. GESTION INFRAESTRUCTURAS TIC','SERVICIO DE GESTION DE INFR, TIC','FORMACION INTERNA', 'SERV, GESTION INFRAESTRUCTURAS TIC','SERVICIOS GESTION INFRAESTRUCTURAS TIC',
       'SERV. GESTION INFRAESTRUCTURAS TIC', 'SERVICIO  GESTION  INFRAESTRUCTURAS TIC']:
        return 'SERV. GESTION INFRAESTRUCTURAS TIC'
    elif subgrupo == 'SANDETEL':
        return 'SANDETEL'
    elif subgrupo in ['SUMINISTROS', 'SUMINISTRO']:
        return 'SUMINISTROS'
    elif subgrupo in ['FORMACION INTERNA']:
        return 'FORMACION INTERNA'
    elif subgrupo in ['REUNIONES, CONFERENCIAS Y CURSOS', 'REUNIONES. CONFERENCIAS Y CURSOS', 'REUNIONES Y CONFERENCIAS', 'REUNIONES', 'REUNIONES,CONFERENCIA Y CURSOS', 'REUNIONES,CONFERENCIAS Y CURSOS','REUNIONES, CONFERENCIAS Y CURSOS ']:
        return 'REUNIONES, CONFERENCIAS Y CURSOS'
    elif subgrupo in ['COMBUSTIBLE', 'COMBUSTIBLE Y LAVADOS', 'COMBUSTIBLE-LAVADO', 'COMBUSTIBLES', 'LAVADOS Y OTROS','COMBUSTIBLE', 'LAVADOS Y OTROS','COMBUSTIBLE,LAVADOS Y OTROS','COMBUSTIBLES,LAVADOS Y OTROS','COMBUSTIBLE Y LAVADO','COMBUSTIBLE, LAVADOS Y OTROS']:
        return 'COMBUSTIBLE Y LAVADOS'
    elif subgrupo in ['GASTOS CONTENCIOSOS', 'GASTOS CONTECIOSOS', 'GASTOS  CONTENCIOSO']:
        return 'GASTOS CONTENCIOSOS'
    elif subgrupo in ['DOCUMENTACION Y PUBLICACIONES','ADQUISICION'	, 'ADQ. LIBROS / DOCUMENTACION','ADQ,LIBROS/DOCUMENTACION', 'ADQ LIBROS/DOCUMENTACION', 'ADQ.LIBROS/DOCUMENTACION', 'PUBLICIDAD Y DOCUMENTACION']:
        return 'DOCUMENTACION Y PUBLICACIONES'
    elif subgrupo in ['PUBLICIDAD Y COMUNICACION', 'CAMPANAS PUBLICIDAD', 'PUBLICIDAD', 'COMUNICACION']:
        return 'PUBLICIDAD Y COMUNICACION'
    elif subgrupo in ['ASISTENCIA SESIONES COMISION CONSULTIVA', 'ASISTENCIA SESIONES COMISION CONSULTIVA', 'ASISTENCIA SESIONES', 'ASISTNCIA SESIONES COMISION CONSULTIVA']:
        return 'ASISTENCIA SESIONES COMISION CONSULTIVA'
    elif subgrupo == 'INDEMNIZACIONES POR RAZON DEL SERVICIO':
        return 'INDEMNIZACIONES POR RAZON DEL SERVICIO'
    elif subgrupo == 'PROTOCOLO':
        return 'PROTOCOLO'
    elif subgrupo == 'COLEGIACION':
        return 'COLEGIACION'
    elif subgrupo == 'IDENTIDAD CORPORATIVA':
        return 'IDENTIDAD CORPORATIVA'
    elif subgrupo == 'PREVENCION RIESGOS LABORALES':
        return 'PREVENCION RIESGOS LABORALES'
    elif subgrupo == 'GASTOS DE REPRESENTACION':
        return 'GASTOS DE REPRESENTACION'
    elif subgrupo == 'TRIBUTOS':
        return 'TRIBUTOS'
    elif subgrupo == 'TRADUCCION':
        return 'TRADUCCION'
    elif subgrupo in ['VESTUARIO PERSONAL LABORAL', 'VESTUARIO']:
        return 'VESTUARIO'
    elif subgrupo in ['MA NTENIMIENTO', 'MANTENIMIENTO COCHE']:
        return 'MANTENIMIENTO'
    elif subgrupo == 'PLANES Y PROGRAMAS':
        return 'PLANES'
    elif subgrupo == 'POSTAL':
        return 'POSTAL'
    elif subgrupo == 'CENTRA':
        return 'CENTRA'
    elif subgrupo == 'COMISION SELECCION CONCURSO':
        return 'COMISION SELECCION CONCURSO'
    else:
        return subgrupo

df['subgrupo'] = df['subgrupo'].apply(quitar_tildes)


df['df_subgrupo'] = df['subgrupo'].map(lambda x: discretiza_subgrupo(x))

# %%
# Obtener las frecuencias de la columna 'subgrupo'
frecuencias = df['df_subgrupo'].value_counts()

# Convertir a un DataFrame
tabla_frecuencias = frecuencias.reset_index()

# Renombrar las columnas para mayor claridad
tabla_frecuencias.columns = ['subgrupo', 'frecuencia']

# Ensure the 'subgrupo' column is of type string
tabla_frecuencias['subgrupo'] = tabla_frecuencias['subgrupo'].astype(str)

# Ordenar alfabéticamente por la columna 'subgrupo'
tabla_frecuencias_sorted = tabla_frecuencias.sort_values(by='subgrupo')



# Mostrar la tabla ordenada
tabla_frecuencias_sorted
# Out:
#                                    subgrupo  frecuencia
# 14              ADQ, LIBROS / DOCUMENTACION          55
# 16  ASISTENCIA SESIONES COMISION CONSULTIVA          29
# 17                                   CENTRA          21
# 20                              COLEGIACION          16
# 5                     COMBUSTIBLE Y LAVADOS         127
# 23              COMISION SELECCION CONCURSO           4
# 1                                    DIETAS         446
# 10            DOCUMENTACION Y PUBLICACIONES          80
# 8                       GASTOS CONTENCIOSOS          88
# 24                 GASTOS DE REPRESENTACION           1
# 26                    IDENTIDAD CORPORATIVA           1
# 18   INDEMNIZACIONES POR RAZON DEL SERVICIO          19
# 2                             MANTENIMIENTO         373
# 3         MATERIAL INFORMATICO Y DE OFICINA         275
# 12                                   PLANES          61
# 6                                    POSTAL         120
# 22             PREVENCION RIESGOS LABORALES           6
# 19                                PROTOCOLO          17
# 15                PUBLICIDAD Y COMUNICACION          32
# 9          REUNIONES, CONFERENCIAS Y CURSOS          82
# 11                                 SANDETEL          79
# 7        SERV. GESTION INFRAESTRUCTURAS TIC          94
# 4                               SUMINISTROS         136
# 0                      TELEFONIA E INTERNET         469
# 25                               TRADUCCION           1
# 13                                 TRIBUTOS          57
# 21                                VESTUARIO          15

# %%
x=df['df_subgrupo'].value_counts()
print(x,x.index)
sns.barplot(x=x.values, y=x.index, alpha=0.8)
# Out:
# df_subgrupo
# TELEFONIA E INTERNET                       469
# DIETAS                                     446
# MANTENIMIENTO                              373
# MATERIAL INFORMATICO Y DE OFICINA          275
# SUMINISTROS                                136
# COMBUSTIBLE Y LAVADOS                      127
# POSTAL                                     120
# SERV. GESTION INFRAESTRUCTURAS TIC          94
# GASTOS CONTENCIOSOS                         88
# REUNIONES, CONFERENCIAS Y CURSOS            82
# DOCUMENTACION Y PUBLICACIONES               80
# SANDETEL                                    79
# PLANES                                      61
# TRIBUTOS                                    57
# ADQ, LIBROS / DOCUMENTACION                 55
# PUBLICIDAD Y COMUNICACION                   32
# ASISTENCIA SESIONES COMISION CONSULTIVA     29
# CENTRA                                      21
# INDEMNIZACIONES POR RAZON DEL SERVICIO      19
# PROTOCOLO                                   17
# COLEGIACION                                 16
# VESTUARIO                                   15
# PREVENCION RIESGOS LABORALES                 6
# COMISION SELECCION CONCURSO                  4
# GASTOS DE REPRESENTACION                     1
# TRADUCCION                                   1
# IDENTIDAD CORPORATIVA                        1
# Name: count, dtype: int64 Index(['TELEFONIA E INTERNET', 'DIETAS', 'MANTENIMIENTO',
#        'MATERIAL INFORMATICO Y DE OFICINA', 'SUMINISTROS',
#        'COMBUSTIBLE Y LAVADOS', 'POSTAL', 'SERV. GESTION INFRAESTRUCTURAS TIC',
#        'GASTOS CONTENCIOSOS', 'REUNIONES, CONFERENCIAS Y CURSOS',
#        'DOCUMENTACION Y PUBLICACIONES', 'SANDETEL', 'PLANES', 'TRIBUTOS',
#        'ADQ, LIBROS / DOCUMENTACION', 'PUBLICIDAD Y COMUNICACION',
#        'ASISTENCIA SESIONES COMISION CONSULTIVA', 'CENTRA',
#        'INDEMNIZACIONES POR RAZON DEL SERVICIO', 'PROTOCOLO', 'COLEGIACION',
#        'VESTUARIO', 'PREVENCION RIESGOS LABORALES',
#        'COMISION SELECCION CONCURSO', 'GASTOS DE REPRESENTACION', 'TRADUCCION',
#        'IDENTIDAD CORPORATIVA'],
#       dtype='object', name='df_subgrupo')
# <Axes: ylabel='df_subgrupo'>

# %%
df['df_subgrupo'].info
# Out:
# <bound method Series.info of 0                    TELEFONIA E INTERNET
# 1                   COMBUSTIBLE Y LAVADOS
# 2                               PROTOCOLO
# 3                    TELEFONIA E INTERNET
# 4                    TELEFONIA E INTERNET
#                       ...
# 2699                        MANTENIMIENTO
# 2700    MATERIAL INFORMATICO Y DE OFICINA
# 2701        DOCUMENTACION Y PUBLICACIONES
# 2702                               PLANES
# 2703                             SANDETEL
# Name: df_subgrupo, Length: 2704, dtype: object>

# %% [markdown]
# ###Consolidación de la variable denominacion_acreedor

# %%
df['denominacion_acreedor'].value_counts()
# Obtener las frecuencias de la columna 'subgrupo'
# Out:
# denominacion_acreedor
# SDAD AND PARA EL DESARROLLO DE LAS     147
# TELEFONICA DE ESPAÑA SAU TELEFONICA    140
# VODAFONE ESPAÑA SA                     123
# MANUEL MEDINA GUERRERO                 119
# SOCIEDAD ESTATAL CORREOS Y TELEGRAF    115
#                                       ...
# RAFAEL RUBIO NUÑEZ                       1
# JUAN CARLOS GARCIA MELIAN                1
# COMBUST, MAYO BAM SOLRED SA              1
# BREAD&MORE SL                            1
# FAMILYDIFERENT SL                        1
# Name: count, Length: 355, dtype: int64

# %%
x=df['denominacion_acreedor'].value_counts()
print(x,x.index)
sns.barplot(x=x.values, y=x.index, alpha=0.8)
# Out:
# denominacion_acreedor
# SDAD AND PARA EL DESARROLLO DE LAS     147
# TELEFONICA DE ESPAÑA SAU TELEFONICA    140
# VODAFONE ESPAÑA SA                     123
# MANUEL MEDINA GUERRERO                 119
# SOCIEDAD ESTATAL CORREOS Y TELEGRAF    115
#                                       ...
# RAFAEL RUBIO NUÑEZ                       1
# JUAN CARLOS GARCIA MELIAN                1
# COMBUST, MAYO BAM SOLRED SA              1
# BREAD&MORE SL                            1
# FAMILYDIFERENT SL                        1
# Name: count, Length: 355, dtype: int64 Index(['SDAD AND PARA EL DESARROLLO DE LAS',
#        'TELEFONICA DE ESPAÑA SAU TELEFONICA', 'VODAFONE ESPAÑA SA',
#        'MANUEL MEDINA GUERRERO', 'SOCIEDAD ESTATAL CORREOS Y TELEGRAF',
#        'UTE TDE TME DCLXXX', 'PURIFY HISPANIA SL', 'ENRIQUE GAVIRA SANCHEZ',
#        'SOLRED SA', 'PEDREGOSA SL',
#        ...
#        'ISAAC MARTIN DELGADO', 'JOSE FELIX ONTAÑON CARMONA',
#        'FRANCISCO JAVIER MARTIN CAVANNA', 'LAURA CHAQUES BONAFONT',
#        'MARTIN MARIA RAZQUIN LIZARRAGA', 'RAFAEL RUBIO NUÑEZ',
#        'JUAN CARLOS GARCIA MELIAN', 'COMBUST, MAYO BAM SOLRED SA',
#        'BREAD&MORE SL', 'FAMILYDIFERENT SL'],
#       dtype='object', name='denominacion_acreedor', length=355)
# <Axes: ylabel='denominacion_acreedor'>

# %%
import unicodedata


def consolidar_acre(x):
  if x=="AMADOR MARTINEZ HERRERA" or x=="AMADOR MARTNEZ HERRERA":
    return "AMADOR MARTINEZ HERRERA"
  elif x=="ARTES GRAFICA MORENO SL" or x=="ARTES GRAFICA MORENO SLL" or x=="ARTES GRAFICAS MORENO SL":
    return "ARTES GRAFICAS MORENO SL"
  elif x=="JESUS JIMENEZ LOPEZ" or x=="JESUS JIMENEZ LOPEZ" or x=="JESUS JIMINEZ LOPEZ" or x=="JJESUS JIMENEZ LOPEZ":
    return "JESUS JIMENEZ LOPEZ"
  elif x=="RICOH ESPANA SLU" or x=="RICOH ESPANA SLU" or x=="RICOH ESPANA, SLU":
    return "RICOH ESPANA, SLU"
  elif x=="SOLUTIA INNOVAWORD TECHNOLOGIES SL" or x=="SOLUTIA INNOVAWORLD TECHNOLOGIES S" or x=="SOLUTIA INNOVAWORLD TECHNOLOGIES, S":
    return "SOLUTIA INNOVAWORD TECHNOLOGIES SL"
  elif x=="TK ELEVADORES ESPANA SL" or x=="TK ELEVADORES ESPANAA SL":
    return "TK ELEVADORES ESPANAA SL"
  elif x=="TK ELEVADORES ESPANA SL" or x=="TK ELEVADORES ESPANAA SL":
    return "TK ELEVADORES ESPANAA SL"
  elif x=="VISTALEGRE SOLUTIONS S,L," or x=="TK ELEVADORES ESPANAA SL":
    return "VISTALEGRE SOLUTIONS S,L"
  else:
    return x

df['denominacion_acreedor'] = df['denominacion_acreedor'].map(lambda x: consolidar_acre(x))

# %%
x=df['denominacion_acreedor'].value_counts()
print(x,x.index)
sns.barplot(x=x.values, y=x.index, alpha=0.8)
# Out:
# denominacion_acreedor
# SDAD AND PARA EL DESARROLLO DE LAS     147
# TELEFONICA DE ESPAÑA SAU TELEFONICA    140
# VODAFONE ESPAÑA SA                     123
# MANUEL MEDINA GUERRERO                 119
# SOCIEDAD ESTATAL CORREOS Y TELEGRAF    115
#                                       ...
# FUNDACIÓN NOVAGOB                        1
# JESUS JIMENEZ LO PEZ                     1
# AGUSTI CERRILLO MARTINEZ                 1
# ANA ISABEL BELTRAN GOMEZ                 1
# FAMILYDIFERENT SL                        1
# Name: count, Length: 351, dtype: int64 Index(['SDAD AND PARA EL DESARROLLO DE LAS',
#        'TELEFONICA DE ESPAÑA SAU TELEFONICA', 'VODAFONE ESPAÑA SA',
#        'MANUEL MEDINA GUERRERO', 'SOCIEDAD ESTATAL CORREOS Y TELEGRAF',
#        'UTE TDE TME DCLXXX', 'PURIFY HISPANIA SL', 'ENRIQUE GAVIRA SANCHEZ',
#        'SOLRED SA', 'PEDREGOSA SL',
#        ...
#        'CONSEJO GENERAL DE LA ABOGACIA ESPA',
#        'VIAJE A MADRID 13,10 GESTORA DE VIAJES Y NEGOCIOS SL',
#        'ALTERNATIVA ECOLÓGICA ANDALUCIA SL',
#        'BAM CONTR 2022 549587 GESTORA DE VIAJES Y NEGOCIOS SL',
#        'VALORA PREVENCION SLU', 'FUNDACIÓN NOVAGOB', 'JESUS JIMENEZ LO PEZ',
#        'AGUSTI CERRILLO MARTINEZ', 'ANA ISABEL BELTRAN GOMEZ',
#        'FAMILYDIFERENT SL'],
#       dtype='object', name='denominacion_acreedor', length=351)
# <Axes: ylabel='denominacion_acreedor'>

# %% [markdown]
# Procesamiento de texto a las variable denominacion_factura y denominacion_acreedor

# %%
# !pip install category-encoders
# Out:
# zsh:1: command not found: pip

# %%
df
# Out:
#      fecha_entrada_registro  importe_total           grupo_gastos  \
# 0                2019-01-10           0.33         COMUNICACIONES
# 1                2021-02-03           1.00       VEHICULO OFICIAL
# 2                2023-06-26           1.00  ACTIVIDAD DEL CONSEJO
# 3                2016-09-08           1.17         COMUNICACIONES
# 4                2016-09-08           1.17         COMUNICACIONES
# ...                     ...            ...                    ...
# 2699             2020-06-02        9376.87                   SEDE
# 2700             2021-11-26        9408.57  ACTIVIDAD DEL CONSEJO
# 2701             2022-03-02        9519.07  ACTIVIDAD DEL CONSEJO
# 2702             2021-12-21        9747.51  ACTIVIDAD DEL CONSEJO
# 2703             2020-01-08        9765.83             ENCOMIENDA
#
#                              subgrupo       denominacion_factura  \
# 0                  TELEFONIA-INTERNET  LOTE 5 VOZ FIJA SEPTIEMBR
# 1         COMBUSTIBLE,LAVADOS Y OTROS           LAVADOS ENERO 21
# 2                           PROTOCOLO  COMISION ENTE, C, PROTOC,
# 3                  TELEFONIA-INTERNET   LOTE 9 AC INTERN 2 MARZO
# 4                  TELEFONIA-INTERNET   LOTE 9 AC INTERN 2 ABRIL
# ...                               ...                        ...
# 2699                    MANTENIMIENTO    VIG–SEG,CTPDA 1 A 31/05
# 2700  MATERIAL INFORMATICO Y  OFICINA      CABINA ALMACENAM, SAN
# 2701    DOCUMENTACION Y PUBLICACIONES       RENOV,SUSCRIPBD 2022
# 2702               PLANES Y PROGRAMAS   DES, DE SIST,INF, NOV,21
# 2703                         SANDETEL      GEST INF TIC DIC 2019
#
#                     denominacion_acreedor  grupo_gastos_n  df_GrupoGastos  \
# 0     TELEFONICA DE ESPAÑA SAU TELEFONICA  COMUNICACIONES               1
# 1                               SOLRED SA        VEHICULO               6
# 2     EXCMO CABILDO DE LA S M Y P I CATED       ACTIVIDAD               0
# 3     TELEFONICA DE ESPAÑA SAU TELEFONICA  COMUNICACIONES               1
# 4     TELEFONICA DE ESPAÑA SAU TELEFONICA  COMUNICACIONES               1
# ...                                   ...             ...             ...
# 2699                    SECURITY WORLD SA            SEDE               5
# 2700   SOLUTIA INNOVAWORD TECHNOLOGIES SL       ACTIVIDAD               0
# 2701               EDITORIAL ARANZADI SAU       ACTIVIDAD               0
# 2702              SOLTEL IT SOLUTIONS SLU       ACTIVIDAD               0
# 2703   SDAD AND PARA EL DESARROLLO DE LAS     ENCOMIENDAS               3
#
#                             df_subgrupo
# 0                  TELEFONIA E INTERNET
# 1                 COMBUSTIBLE Y LAVADOS
# 2                             PROTOCOLO
# 3                  TELEFONIA E INTERNET
# 4                  TELEFONIA E INTERNET
# ...                                 ...
# 2699                      MANTENIMIENTO
# 2700  MATERIAL INFORMATICO Y DE OFICINA
# 2701      DOCUMENTACION Y PUBLICACIONES
# 2702                             PLANES
# 2703                           SANDETEL
#
# [2704 rows x 9 columns]

# %% [markdown]
# Procesamiento de la variable fecha_entrada_registro

# %%
# 1.La columna 'fecha_entrada_registro' está en formato datetime
df['fecha_entrada_registro'] = pd.to_datetime(df['fecha_entrada_registro'], errors='coerce')

# 2. Extraer atributos temporales relevantes
df['mes'] = df['fecha_entrada_registro'].dt.month  # Mes del año (1-12)
df['bimestre'] = (df['fecha_entrada_registro'].dt.month - 1) // 2 + 1  # Bimestre (1-6)
df['trimestre'] = df['fecha_entrada_registro'].dt.quarter  # Trimestre (1-4)
df['semana_anio'] = df['fecha_entrada_registro'].dt.isocalendar().week  # Semana del año (1-52)
df['anio'] = df['fecha_entrada_registro'].dt.year  # Año
df['df_fecha'] = df['fecha_entrada_registro'].dt.day * 1000000 + df['fecha_entrada_registro'].dt.month * 10000 + df['fecha_entrada_registro'].dt.year

# 3. Calcular importes medios por diferentes períodos

# Importe medio por mes
importe_medio_mes = df.groupby(['anio', 'mes'])['importe_total'].mean().reset_index()
importe_medio_mes.columns = ['anio', 'mes', 'importe_medio_mes']

# Importe medio por bimestre
importe_medio_bimestre = df.groupby(['anio', 'bimestre'])['importe_total'].mean().reset_index()
importe_medio_bimestre.columns = ['anio', 'bimestre', 'importe_medio_bimestre']

# Importe medio por trimestre
importe_medio_trimestre = df.groupby(['anio', 'trimestre'])['importe_total'].mean().reset_index()
importe_medio_trimestre.columns = ['anio', 'trimestre', 'importe_medio_trimestre']

# Importe medio por semana del año
importe_medio_semana = df.groupby(['anio', 'semana_anio'])['importe_total'].mean().reset_index()
importe_medio_semana.columns = ['anio', 'semana_anio', 'importe_medio_semana']

# 4. Agregar estas nuevas tablas de importes medios al DataFrame original (opcional)
df = pd.merge(df, importe_medio_mes, on=['anio', 'mes'], how='left')
df = pd.merge(df, importe_medio_bimestre, on=['anio', 'bimestre'], how='left')
df = pd.merge(df, importe_medio_trimestre, on=['anio', 'trimestre'], how='left')
df = pd.merge(df, importe_medio_semana, on=['anio', 'semana_anio'], how='left')

# Guardar el DataFrame con las nuevas columnas en un archivo XLSX si es necesario
df.to_excel('data_with_fechas.xlsx', index=False)

# %%
print(df.dtypes)
# Out:
# fecha_entrada_registro     datetime64[ns]
# importe_total                     float64
# grupo_gastos                       object
# subgrupo                           object
# denominacion_factura               object
# denominacion_acreedor              object
# grupo_gastos_n                     object
# df_GrupoGastos                      int64
# df_subgrupo                        object
# mes                                 int32
# bimestre                            int32
# trimestre                           int32
# semana_anio                        UInt32
# anio                                int32
# df_fecha                            int32
# importe_medio_mes                 float64
# importe_medio_bimestre            float64
# importe_medio_trimestre           float64
# importe_medio_semana              float64
# dtype: object

# %%
# Convertir la columna a datetime
df['fecha_entrada_registro'] = pd.to_datetime(df['fecha_entrada_registro'])

# Crear una nueva columna para el mes
df['mes'] = df['fecha_entrada_registro'].dt.to_period('M')

# Agrupar por mes
gastos_por_mes = df.groupby('mes')['importe_total'].sum()

# Graficar
plt.figure(figsize=(25, 5))
plt.plot(gastos_por_mes.index.astype(str), gastos_por_mes.values, marker='o')
plt.title('Gastos Totales por Mes')
plt.xlabel('Mes')
plt.ylabel('Importe Total')
plt.xticks(rotation=45)
plt.grid()
plt.show()

# %%
# Lista de nombres de las columnas numéricas
columnas = df.select_dtypes(include=['number']).columns

# Configurar la figura y los ejes para los subplots
fig, axes = plt.subplots(5, 2, figsize=(20, 15))

# Dibujar cada boxplot en su correspondiente subplot
for i, ax in enumerate(axes.flatten()):
    if i < len(columnas):  # Asegúrate de no exceder el número de columnas
        df.boxplot(column=columnas[i], ax=ax)
        ax.set_title(columnas[i])
        ax.set_ylabel('Valores')  # Etiqueta para el eje y

# Ajustar el layout
plt.tight_layout()
plt.show()

# %% [markdown]
# ##Correlación de las variables

# %%
f,ax = plt.subplots(figsize=(7,6))
sns.heatmap(df.select_dtypes(include=['number']).corr(), annot=True, linewidths=.18, fmt= '.1f',cmap= 'coolwarm', ax=ax)
# Out:
# <Axes: >

# %% [markdown]
# Las variables importe_medio_mes,  importe_medio_bimestre,  importe_medio_trimestre y importe_medio_semana son variables que están correlacionadas ya que se han calculado desde la variable importe total. Eliminamos importe_medio_bimestre , importe_medio_trimestre y importe_medio_semana. De igual manera pasa con las variables mes, bimestre,trimestre, semana_anio y anio.

# %%
df.drop(['importe_medio_bimestre','importe_medio_trimestre','importe_medio_semana','bimestre','trimestre','semana_anio','anio'], axis=1, inplace=True)

# %%
f,ax = plt.subplots(figsize=(7,6))
sns.heatmap(df.select_dtypes(include=['number']).corr(), annot=True, linewidths=.18, fmt= '.1f',cmap= 'coolwarm', ax=ax)
# Out:
# <Axes: >

# %%
# Boxplot para ver la distribución de importe_total por grupo_gastos
plt.figure(figsize=(12, 6))
sns.boxplot(x='grupo_gastos_n', y='importe_total', data=df)
plt.title('Distribución de Importe Total por Grupo de Gastos')
plt.xticks(rotation=45)
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Calcular la suma de importe_total por grupo de gastos
suma_importe = df.groupby('grupo_gastos_n')['importe_total'].sum().reset_index()

# Configurar la figura
plt.figure(figsize=(12, 6))

# Crear un gráfico de barras con colores diferentes para cada grupo
sns.barplot(x='grupo_gastos_n', y='importe_total', data=suma_importe, palette='Set2')

# Configurar el título y las etiquetas
plt.title('Total de Importe por Grupo de Gastos')
plt.xlabel('Grupo de Gastos')
plt.ylabel('Importe Total')
plt.xticks(rotation=45)

# Mostrar el gráfico
plt.show()
# Out:
# /var/folders/4x/mfxr0f553zg10gj4tr4nrlb40000gn/T/ipykernel_53313/2143128156.py:11: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='grupo_gastos_n', y='importe_total', data=suma_importe, palette='Set2')

# %%
from category_encoders import BinaryEncoder
# Función de preprocesamiento de texto
def preprocesar(texto):
    # Quitar tildes
    texto = quitar_tildes(texto)
    
    # Convertir a minúsculas
    texto = texto.lower()
    
    # Eliminar números
    texto = re.sub(r'\d+', '', texto)
    
    # Eliminar puntuación
    texto = texto.translate(str.maketrans('', '', string.punctuation))
    
    # Eliminar stopwords
    stop_words = set(stopwords.words('spanish'))
    palabras = word_tokenize(texto)
    palabras = [palabra for palabra in palabras if palabra not in stop_words]
    
    # Stemming (opcional)
    ps = PorterStemmer()
    palabras = [ps.stem(palabra) for palabra in palabras]
    
    # Volver a unir las palabras procesadas en una cadena
    texto_procesado = ' '.join(palabras)
    
    return texto_procesado

# Aplicar el preprocesamiento al DataFrame
df['df_denominacion_factura'] = df['denominacion_factura'].apply(preprocesar)
df['df_denominacion_acreedor'] = df['denominacion_acreedor'].apply(preprocesar)

# Convertir las columnas procesadas a tipo categórico antes de aplicar Binary Encoding
df['df_denominacion_factura'] = df['df_denominacion_factura'].astype('category')
df['df_denominacion_acreedor'] = df['df_denominacion_acreedor'].astype('category')

# Codificar las etiquetas (Denominacion Acreedor)
label_encoder_acreedor = LabelEncoder()
label_encoder_factura = LabelEncoder()

# Aplicar Label Encoding a 'df_denominacion_acreedor'
df['denominacion_acreedor_label'] = label_encoder_acreedor.fit_transform(df['df_denominacion_acreedor'])

# Aplicar Label Encoding a 'df_denominacion_factura'
df['denominacion_factura_label'] = label_encoder_factura.fit_transform(df['df_denominacion_factura'])

# Aplicar Binary Encoding a las columnas originales preprocesadas
binary_encoder_acreedor = BinaryEncoder(cols=['df_denominacion_acreedor'])
binary_encoder_factura = BinaryEncoder(cols=['df_denominacion_factura'])

# Transformar el DataFrame
df_acreedor_binario = binary_encoder_acreedor.fit_transform(df)
df_factura_binario = binary_encoder_factura.fit_transform(df)


df = pd.concat([df, df_acreedor_binario.add_prefix('bin_acreedor_'), df_factura_binario.add_prefix('bin_factura_')], axis=1)

# %%
print(df.shape)
print(df.info())

df.to_excel("Basededatos_sindummies.xlsx",)
# Out:
# (2704, 66)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2704 entries, 0 to 2703
# Data columns (total 66 columns):
#  #   Column                                    Non-Null Count  Dtype
# ---  ------                                    --------------  -----
#  0   fecha_entrada_registro                    2704 non-null   datetime64[ns]
#  1   importe_total                             2704 non-null   float64
#  2   grupo_gastos                              2704 non-null   object
#  3   subgrupo                                  2704 non-null   object
#  4   denominacion_factura                      2704 non-null   object
#  5   denominacion_acreedor                     2703 non-null   object
#  6   grupo_gastos_n                            2704 non-null   object
#  7   df_GrupoGastos                            2704 non-null   int64
#  8   df_subgrupo                               2704 non-null   object
#  9   mes                                       2704 non-null   period[M]
#  10  df_fecha                                  2704 non-null   int32
#  11  importe_medio_mes                         2704 non-null   float64
#  12  df_denominacion_factura                   2704 non-null   category
#  13  df_denominacion_acreedor                  2704 non-null   category
#  14  denominacion_acreedor_label               2704 non-null   int64
#  15  denominacion_factura_label                2704 non-null   int64
#  16  bin_acreedor_fecha_entrada_registro       2704 non-null   datetime64[ns]
#  17  bin_acreedor_importe_total                2704 non-null   float64
#  18  bin_acreedor_grupo_gastos                 2704 non-null   object
#  19  bin_acreedor_subgrupo                     2704 non-null   object
#  20  bin_acreedor_denominacion_factura         2704 non-null   object
#  21  bin_acreedor_denominacion_acreedor        2703 non-null   object
#  22  bin_acreedor_grupo_gastos_n               2704 non-null   object
#  23  bin_acreedor_df_GrupoGastos               2704 non-null   int64
#  24  bin_acreedor_df_subgrupo                  2704 non-null   object
#  25  bin_acreedor_mes                          2704 non-null   period[M]
#  26  bin_acreedor_df_fecha                     2704 non-null   int32
#  27  bin_acreedor_importe_medio_mes            2704 non-null   float64
#  28  bin_acreedor_df_denominacion_factura      2704 non-null   category
#  29  bin_acreedor_df_denominacion_acreedor_0   2704 non-null   int64
#  30  bin_acreedor_df_denominacion_acreedor_1   2704 non-null   int64
#  31  bin_acreedor_df_denominacion_acreedor_2   2704 non-null   int64
#  32  bin_acreedor_df_denominacion_acreedor_3   2704 non-null   int64
#  33  bin_acreedor_df_denominacion_acreedor_4   2704 non-null   int64
#  34  bin_acreedor_df_denominacion_acreedor_5   2704 non-null   int64
#  35  bin_acreedor_df_denominacion_acreedor_6   2704 non-null   int64
#  36  bin_acreedor_df_denominacion_acreedor_7   2704 non-null   int64
#  37  bin_acreedor_df_denominacion_acreedor_8   2704 non-null   int64
#  38  bin_acreedor_denominacion_acreedor_label  2704 non-null   int64
#  39  bin_acreedor_denominacion_factura_label   2704 non-null   int64
#  40  bin_factura_fecha_entrada_registro        2704 non-null   datetime64[ns]
#  41  bin_factura_importe_total                 2704 non-null   float64
#  42  bin_factura_grupo_gastos                  2704 non-null   object
#  43  bin_factura_subgrupo                      2704 non-null   object
#  44  bin_factura_denominacion_factura          2704 non-null   object
#  45  bin_factura_denominacion_acreedor         2703 non-null   object
#  46  bin_factura_grupo_gastos_n                2704 non-null   object
#  47  bin_factura_df_GrupoGastos                2704 non-null   int64
#  48  bin_factura_df_subgrupo                   2704 non-null   object
#  49  bin_factura_mes                           2704 non-null   period[M]
#  50  bin_factura_df_fecha                      2704 non-null   int32
#  51  bin_factura_importe_medio_mes             2704 non-null   float64
#  52  bin_factura_df_denominacion_factura_0     2704 non-null   int64
#  53  bin_factura_df_denominacion_factura_1     2704 non-null   int64
#  54  bin_factura_df_denominacion_factura_2     2704 non-null   int64
#  55  bin_factura_df_denominacion_factura_3     2704 non-null   int64
#  56  bin_factura_df_denominacion_factura_4     2704 non-null   int64
#  57  bin_factura_df_denominacion_factura_5     2704 non-null   int64
#  58  bin_factura_df_denominacion_factura_6     2704 non-null   int64
#  59  bin_factura_df_denominacion_factura_7     2704 non-null   int64
#  60  bin_factura_df_denominacion_factura_8     2704 non-null   int64
#  61  bin_factura_df_denominacion_factura_9     2704 non-null   int64
#  62  bin_factura_df_denominacion_factura_10    2704 non-null   int64
#  63  bin_factura_df_denominacion_acreedor      2704 non-null   category
#  64  bin_factura_denominacion_acreedor_label   2704 non-null   int64
#  65  bin_factura_denominacion_factura_label    2704 non-null   int64
# dtypes: category(4), datetime64[ns](3), float64(6), int32(3), int64(29), object(18), period[M](3)
# memory usage: 1.4+ MB
# None

# %% [markdown]
# ##Variables dummies

# %%
import pandas as pd
from sklearn.preprocessing import OneHotEncoder
from category_encoders import BinaryEncoder

# Definir el OneHotEncoder con la opción de salida como pandas DataFrame
encoder = OneHotEncoder(sparse_output=False)

# Crear un DataFrame con los nombres de las columnas generadas por OneHotEncoder


# Codificación de la columna "df_subrupo"
subgrupo_column = df[["df_subgrupo"]]
subgrupo_encoded = encoder.fit_transform(subgrupo_column)

# Crear un DataFrame con los nombres de las columnas generadas por OneHotEncoder
subgrupo_encoded_df = pd.DataFrame(subgrupo_encoded, columns=encoder.get_feature_names_out(["df_subgrupo"]))
df = pd.concat([df, subgrupo_encoded_df], axis=1)



df.to_excel('Basededatos_dummies.xlsx', index=False)

# %%
df.columns
# Out:
# Index(['fecha_entrada_registro', 'importe_total', 'grupo_gastos', 'subgrupo',
#        'denominacion_factura', 'denominacion_acreedor', 'grupo_gastos_n',
#        'df_GrupoGastos', 'df_subgrupo', 'mes', 'df_fecha', 'importe_medio_mes',
#        'df_denominacion_factura', 'df_denominacion_acreedor',
#        'denominacion_acreedor_label', 'denominacion_factura_label',
#        'bin_acreedor_fecha_entrada_registro', 'bin_acreedor_importe_total',
#        'bin_acreedor_grupo_gastos', 'bin_acreedor_subgrupo',
#        'bin_acreedor_denominacion_factura',
#        'bin_acreedor_denominacion_acreedor', 'bin_acreedor_grupo_gastos_n',
#        'bin_acreedor_df_GrupoGastos', 'bin_acreedor_df_subgrupo',
#        'bin_acreedor_mes', 'bin_acreedor_df_fecha',
#        'bin_acreedor_importe_medio_mes',
#        'bin_acreedor_df_denominacion_factura',
#        'bin_acreedor_df_denominacion_acreedor_0',
#        'bin_acreedor_df_denominacion_acreedor_1',
#        'bin_acreedor_df_denominacion_acreedor_2',
#        'bin_acreedor_df_denominacion_acreedor_3',
#        'bin_acreedor_df_denominacion_acreedor_4',
#        'bin_acreedor_df_denominacion_acreedor_5',
#        'bin_acreedor_df_denominacion_acreedor_6',
#        'bin_acreedor_df_denominacion_acreedor_7',
#        'bin_acreedor_df_denominacion_acreedor_8',
#        'bin_acreedor_denominacion_acreedor_label',
#        'bin_acreedor_denominacion_factura_label',
#        'bin_factura_fecha_entrada_registro', 'bin_factura_importe_total',
#        'bin_factura_grupo_gastos', 'bin_factura_subgrupo',
#        'bin_factura_denominacion_factura', 'bin_factura_denominacion_acreedor',
#        'bin_factura_grupo_gastos_n', 'bin_factura_df_GrupoGastos',
#        'bin_factura_df_subgrupo', 'bin_factura_mes', 'bin_factura_df_fecha',
#        'bin_factura_importe_medio_mes',
#        'bin_factura_df_denominacion_factura_0',
#        'bin_factura_df_denominacion_factura_1',
#        'bin_factura_df_denominacion_factura_2',
#        'bin_factura_df_denominacion_factura_3',
#        'bin_factura_df_denominacion_factura_4',
#        'bin_factura_df_denominacion_factura_5',
#        'bin_factura_df_denominacion_factura_6',
#        'bin_factura_df_denominacion_factura_7',
#        'bin_factura_df_denominacion_factura_8',
#        'bin_factura_df_denominacion_factura_9',
#        'bin_factura_df_denominacion_factura_10',
#        'bin_factura_df_denominacion_acreedor',
#        'bin_factura_denominacion_acreedor_label',
#        'bin_factura_denominacion_factura_label',
#        'df_subgrupo_ADQ, LIBROS / DOCUMENTACION',
#        'df_subgrupo_ASISTENCIA SESIONES COMISION CONSULTIVA',
#        'df_subgrupo_CENTRA', 'df_subgrupo_COLEGIACION',
#        'df_subgrupo_COMBUSTIBLE Y LAVADOS',
#        'df_subgrupo_COMISION SELECCION CONCURSO', 'df_subgrupo_DIETAS',
#        'df_subgrupo_DOCUMENTACION Y PUBLICACIONES',
#        'df_subgrupo_GASTOS CONTENCIOSOS',
#        'df_subgrupo_GASTOS DE REPRESENTACION',
#        'df_subgrupo_IDENTIDAD CORPORATIVA',
#        'df_subgrupo_INDEMNIZACIONES POR RAZON DEL SERVICIO',
#        'df_subgrupo_MANTENIMIENTO',
#        'df_subgrupo_MATERIAL INFORMATICO Y DE OFICINA', 'df_subgrupo_PLANES',
#        'df_subgrupo_POSTAL', 'df_subgrupo_PREVENCION RIESGOS LABORALES',
#        'df_subgrupo_PROTOCOLO', 'df_subgrupo_PUBLICIDAD Y COMUNICACION',
#        'df_subgrupo_REUNIONES, CONFERENCIAS Y CURSOS', 'df_subgrupo_SANDETEL',
#        'df_subgrupo_SERV. GESTION INFRAESTRUCTURAS TIC',
#        'df_subgrupo_SUMINISTROS', 'df_subgrupo_TELEFONIA E INTERNET',
#        'df_subgrupo_TRADUCCION', 'df_subgrupo_TRIBUTOS',
#        'df_subgrupo_VESTUARIO'],
#       dtype='object')

# %%
d1=df[['df_denominacion_acreedor','denominacion_acreedor_label']]

# Exportar la tabla a formato LaTeX
latex_table = d1.head().to_latex(index=False)  # index=False elimina la columna de índices

# Guardar la tabla en un archivo .tex
with open('tabla_facturacion.tex', 'w') as f:
    f.write(latex_table)

# Imprimir el código LaTeX en consola (opcional)
print(latex_table)
# Out:
# \begin{tabular}{lr}
# \toprule
# df_denominacion_acreedor & denominacion_acreedor_label \\
# \midrule
# telefonica espana sau telefonica & 290 \\
# solr sa & 279 \\
# excmo cabildo s m p i cate & 109 \\
# telefonica espana sau telefonica & 290 \\
# telefonica espana sau telefonica & 290 \\
# \bottomrule
# \end{tabular}

# %%
d2=df[['df_denominacion_factura','denominacion_factura_label']]

# Exportar la tabla a formato LaTeX
latex_table = d2.head().to_latex(index=False)  # index=False elimina la columna de índices

# Guardar la tabla en un archivo .tex
with open('tabla_facturacion.tex', 'w') as f:
    f.write(latex_table)

# Imprimir el código LaTeX en consola (opcional)
print(latex_table)
# Out:
# \begin{tabular}{lr}
# \toprule
# df_denominacion_factura & denominacion_factura_label \\
# \midrule
# lote voz fija septiembr & 937 \\
# lavado enero & 612 \\
# comis ent c protoc & 227 \\
# lote ac intern marzo & 670 \\
# lote ac intern abril & 664 \\
# \bottomrule
# \end{tabular}

# %%
df_final = df[['df_GrupoGastos','df_fecha', 'denominacion_acreedor_label','denominacion_factura_label' , 'importe_total' , 'df_subgrupo_ADQ, LIBROS / DOCUMENTACION',
       'df_subgrupo_ASISTENCIA SESIONES COMISION CONSULTIVA',
       'df_subgrupo_CENTRA', 'df_subgrupo_COLEGIACION',
       'df_subgrupo_COMBUSTIBLE Y LAVADOS',
       'df_subgrupo_COMISION SELECCION CONCURSO', 'df_subgrupo_DIETAS',
       'df_subgrupo_DOCUMENTACION Y PUBLICACIONES',
       'df_subgrupo_GASTOS CONTENCIOSOS',
       'df_subgrupo_GASTOS DE REPRESENTACION',
       'df_subgrupo_IDENTIDAD CORPORATIVA',
       'df_subgrupo_INDEMNIZACIONES POR RAZON DEL SERVICIO',
       'df_subgrupo_MANTENIMIENTO',
       'df_subgrupo_MATERIAL INFORMATICO Y DE OFICINA', 'df_subgrupo_PLANES',
       'df_subgrupo_POSTAL', 'df_subgrupo_PREVENCION RIESGOS LABORALES',
       'df_subgrupo_PROTOCOLO', 'df_subgrupo_PUBLICIDAD Y COMUNICACION',
       'df_subgrupo_REUNIONES, CONFERENCIAS Y CURSOS', 'df_subgrupo_SANDETEL',
       'df_subgrupo_SERV. GESTION INFRAESTRUCTURAS TIC',
       'df_subgrupo_SUMINISTROS', 'df_subgrupo_TELEFONIA E INTERNET',
       'df_subgrupo_TRADUCCION', 'df_subgrupo_TRIBUTOS',
       'df_subgrupo_VESTUARIO']]

# %%
df_final2 = df[['df_GrupoGastos','df_fecha', 'denominacion_acreedor_label','denominacion_factura_label' , 'importe_total']]

# %%
df_final.to_excel('Basededatos_final.xlsx', index=False)

# %%
df_final2.to_excel('Basededatos_final_sinsubgrupo.xlsx', index=False)

# %%
df_final.columns
# Out:
# Index(['df_GrupoGastos', 'df_fecha', 'denominacion_acreedor_label',
#        'denominacion_factura_label', 'importe_total',
#        'df_subgrupo_ADQ, LIBROS / DOCUMENTACION',
#        'df_subgrupo_ASISTENCIA SESIONES COMISION CONSULTIVA',
#        'df_subgrupo_CENTRA', 'df_subgrupo_COLEGIACION',
#        'df_subgrupo_COMBUSTIBLE Y LAVADOS',
#        'df_subgrupo_COMISION SELECCION CONCURSO', 'df_subgrupo_DIETAS',
#        'df_subgrupo_DOCUMENTACION Y PUBLICACIONES',
#        'df_subgrupo_GASTOS CONTENCIOSOS',
#        'df_subgrupo_GASTOS DE REPRESENTACION',
#        'df_subgrupo_IDENTIDAD CORPORATIVA',
#        'df_subgrupo_INDEMNIZACIONES POR RAZON DEL SERVICIO',
#        'df_subgrupo_MANTENIMIENTO',
#        'df_subgrupo_MATERIAL INFORMATICO Y DE OFICINA', 'df_subgrupo_PLANES',
#        'df_subgrupo_POSTAL', 'df_subgrupo_PREVENCION RIESGOS LABORALES',
#        'df_subgrupo_PROTOCOLO', 'df_subgrupo_PUBLICIDAD Y COMUNICACION',
#        'df_subgrupo_REUNIONES, CONFERENCIAS Y CURSOS', 'df_subgrupo_SANDETEL',
#        'df_subgrupo_SERV. GESTION INFRAESTRUCTURAS TIC',
#        'df_subgrupo_SUMINISTROS', 'df_subgrupo_TELEFONIA E INTERNET',
#        'df_subgrupo_TRADUCCION', 'df_subgrupo_TRIBUTOS',
#        'df_subgrupo_VESTUARIO'],
#       dtype='object')

# %%
df_final.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2704 entries, 0 to 2703
# Data columns (total 32 columns):
#  #   Column                                               Non-Null Count  Dtype
# ---  ------                                               --------------  -----
#  0   df_GrupoGastos                                       2704 non-null   int64
#  1   df_fecha                                             2704 non-null   int32
#  2   denominacion_acreedor_label                          2704 non-null   int64
#  3   denominacion_factura_label                           2704 non-null   int64
#  4   importe_total                                        2704 non-null   float64
#  5   df_subgrupo_ADQ, LIBROS / DOCUMENTACION              2704 non-null   float64
#  6   df_subgrupo_ASISTENCIA SESIONES COMISION CONSULTIVA  2704 non-null   float64
#  7   df_subgrupo_CENTRA                                   2704 non-null   float64
#  8   df_subgrupo_COLEGIACION                              2704 non-null   float64
#  9   df_subgrupo_COMBUSTIBLE Y LAVADOS                    2704 non-null   float64
#  10  df_subgrupo_COMISION SELECCION CONCURSO              2704 non-null   float64
#  11  df_subgrupo_DIETAS                                   2704 non-null   float64
#  12  df_subgrupo_DOCUMENTACION Y PUBLICACIONES            2704 non-null   float64
#  13  df_subgrupo_GASTOS CONTENCIOSOS                      2704 non-null   float64
#  14  df_subgrupo_GASTOS DE REPRESENTACION                 2704 non-null   float64
#  15  df_subgrupo_IDENTIDAD CORPORATIVA                    2704 non-null   float64
#  16  df_subgrupo_INDEMNIZACIONES POR RAZON DEL SERVICIO   2704 non-null   float64
#  17  df_subgrupo_MANTENIMIENTO                            2704 non-null   float64
#  18  df_subgrupo_MATERIAL INFORMATICO Y DE OFICINA        2704 non-null   float64
#  19  df_subgrupo_PLANES                                   2704 non-null   float64
#  20  df_subgrupo_POSTAL                                   2704 non-null   float64
#  21  df_subgrupo_PREVENCION RIESGOS LABORALES             2704 non-null   float64
#  22  df_subgrupo_PROTOCOLO                                2704 non-null   float64
#  23  df_subgrupo_PUBLICIDAD Y COMUNICACION                2704 non-null   float64
#  24  df_subgrupo_REUNIONES, CONFERENCIAS Y CURSOS         2704 non-null   float64
#  25  df_subgrupo_SANDETEL                                 2704 non-null   float64
#  26  df_subgrupo_SERV. GESTION INFRAESTRUCTURAS TIC       2704 non-null   float64
#  27  df_subgrupo_SUMINISTROS                              2704 non-null   float64
#  28  df_subgrupo_TELEFONIA E INTERNET                     2704 non-null   float64
#  29  df_subgrupo_TRADUCCION                               2704 non-null   float64
#  30  df_subgrupo_TRIBUTOS                                 2704 non-null   float64
#  31  df_subgrupo_VESTUARIO                                2704 non-null   float64
# dtypes: float64(28), int32(1), int64(3)
# memory usage: 665.6 KB

# %%
import pandas as pd
import numpy as np
from scipy.stats import chi2_contingency

# Función para calcular Cramer's V
def cramers_v(tabla_contingencia):
    chi2, _, _, _ = chi2_contingency(tabla_contingencia)
    n = tabla_contingencia.sum().sum()  # Número total de observaciones
    r, k = tabla_contingencia.shape  # Filas y columnas de la tabla de contingencia
    return np.sqrt(chi2 / (n * (min(k-1, r-1))))

# Filtrar las columnas que son dummies de subgrupo
columnas_dummies_subgrupo = [col for col in df.columns if col.startswith('df_subgrupo_')]

# Crear un diccionario para almacenar los resultados
resultados_cramers_v = {}

# Iterar sobre cada dummy de subgrupo y calcular Cramer's V con respecto a df_GrupoGastos
for col in columnas_dummies_subgrupo:
    # Crear tabla de contingencia entre df_GrupoGastos y cada dummy de subgrupo
    tabla_contingencia = pd.crosstab(df_final['df_GrupoGastos'], df_final[col])
    
    # Calcular Cramer's V
    cramers_v_value = cramers_v(tabla_contingencia)
    
    # Almacenar el resultado en el diccionario
    resultados_cramers_v[col] = cramers_v_value

# Convertir el diccionario de resultados en un DataFrame para visualizar
resultados_df = pd.DataFrame(list(resultados_cramers_v.items()), columns=['Subgrupo', 'Cramers_V'])

# Ordenar los resultados por Cramer's V de mayor a menor
resultados_df = resultados_df.sort_values(by='Cramers_V', ascending=False)

# Mostrar los resultados
print(resultados_df)
# Out:
#                                              Subgrupo  Cramers_V
# 4                   df_subgrupo_COMBUSTIBLE Y LAVADOS   0.964657
# 6                                  df_subgrupo_DIETAS   0.935392
# 23                   df_subgrupo_TELEFONIA E INTERNET   0.864300
# 20                               df_subgrupo_SANDETEL   0.856896
# 12                          df_subgrupo_MANTENIMIENTO   0.764176
# 21     df_subgrupo_SERV. GESTION INFRAESTRUCTURAS TIC   0.729980
# 13      df_subgrupo_MATERIAL INFORMATICO Y DE OFICINA   0.531326
# 2                                  df_subgrupo_CENTRA   0.461124
# 22                            df_subgrupo_SUMINISTROS   0.451305
# 15                                 df_subgrupo_POSTAL   0.406594
# 8                     df_subgrupo_GASTOS CONTENCIOSOS   0.289621
# 25                               df_subgrupo_TRIBUTOS   0.287778
# 19       df_subgrupo_REUNIONES, CONFERENCIAS Y CURSOS   0.279254
# 7           df_subgrupo_DOCUMENTACION Y PUBLICACIONES   0.271056
# 14                                 df_subgrupo_PLANES   0.239897
# 0             df_subgrupo_ADQ, LIBROS / DOCUMENTACION   0.227535
# 1   df_subgrupo_ASISTENCIA SESIONES COMISION CONSU...   0.219142
# 11  df_subgrupo_INDEMNIZACIONES POR RAZON DEL SERV...   0.177049
# 18              df_subgrupo_PUBLICIDAD Y COMUNICACION   0.172808
# 17                              df_subgrupo_PROTOCOLO   0.125603
# 3                             df_subgrupo_COLEGIACION   0.121830
# 26                              df_subgrupo_VESTUARIO   0.117939
# 5             df_subgrupo_COMISION SELECCION CONCURSO   0.081010
# 16           df_subgrupo_PREVENCION RIESGOS LABORALES   0.074467
# 10                  df_subgrupo_IDENTIDAD CORPORATIVA   0.030373
# 9                df_subgrupo_GASTOS DE REPRESENTACION   0.030373
# 24                             df_subgrupo_TRADUCCION   0.030373
